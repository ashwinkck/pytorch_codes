# %%
import torch
ver = torch.__version__
print(f"I'mma check the torch version now.....")
print(f"The version is {ver}")
# Out:
# I'mma check the torch version now.....
# The version is 2.12.1+cu130
